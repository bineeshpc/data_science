# %% [markdown]
# [markdown]
# # Data treatment
#
# missing value
# duplicate value
# inconsistent value
# wrong value, irrelevant data
# data format
# special characters

# %%
import pandas as pd

import numpy as np

data = pd.read_csv('data/mtcars_missing.csv')

# %%
data.head()
# Out:
#         car_model    mpg  cyl disp     hp  drat     wt   qsec  vs  am  gear  \
# 0       Mazda RX4   21.0    6  160  110.0  3.90   2.62  16.46   0   1     4
# 1   Mazda RX4 Wag   21.0    6    $  110.0   NaN  2.875      *   0   1     4
# 2      Datsun 710    NaN    4  108    NaN  3.85      ?  18.61   1   1     4
# 3  Hornet 4 Drive  999.0    6  NaN    NaN  3.08  3.215      -   1   0     3
# 4      Datsun 710   22.8    4  NaN   93.0  3.85   2.32  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     1

# %%
data.isnull().sum()
# Out:
# car_model    0
# mpg          1
# cyl          0
# disp         2
# hp           2
# drat         1
# wt           0
# qsec         0
# vs           0
# am           0
# gear         0
# carb         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# car_model    32 non-null object
# mpg          31 non-null float64
# cyl          32 non-null int64
# disp         30 non-null object
# hp           30 non-null float64
# drat         31 non-null float64
# wt           32 non-null object
# qsec         32 non-null object
# vs           32 non-null int64
# am           32 non-null int64
# gear         32 non-null int64
# carb         32 non-null int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.1+ KB

# %%
np.nan # not a number

np.nan == np.nan
# Out:
# False

# %% [markdown]
# 0. Study the info with simple business knowledge
# 1. Find chars used for missing values
# 2. Replace all missing values chars/patterns with Nan
# 3.

# %% [markdown]
# Numerical field having an object means we have some characters in a numerical field
# correct numerical field

# %%
data.disp.sort_values()
# Out:
# 1         $
# 2       108
# 20    120.1
# 26    120.3
# 31      121
# 29      145
# 0       160
# 9     167.6
# 10    167.6
# 5       225
# 8       225
# 7       225
# 11    275.8
# 12    275.8
# 13    275.8
# 30      301
# 22      304
# 21      318
# 23      350
# 28      351
# 6       360
# 24      400
# 16      440
# 15      460
# 14      472
# 19     71.1
# 18     75.7
# 17     78.7
# 25       79
# 27     95.1
# 3       NaN
# 4       NaN
# Name: disp, dtype: object

# %%
data.wt.sort_values(ascending=False)
# Out:
# 2         ?
# 15    5.424
# 16    5.345
# 14     5.25
# 11     4.07
# 24    3.845
# 23     3.84
# 13     3.78
# 12     3.73
# 6      3.57
# 30     3.57
# 21     3.52
# 5      3.46
# 7      3.46
# 8      3.46
# 10     3.44
# 9      3.44
# 22    3.435
# 3     3.215
# 28     3.17
# 1     2.875
# 31     2.78
# 29     2.77
# 0      2.62
# 20    2.465
# 4      2.32
# 17      2.2
# 26     2.14
# 25    1.935
# 19    1.835
# 18    1.615
# 27    1.513
# Name: wt, dtype: object

# %%
data.qsec.sort_values(ascending=True)
# Out:
# 1         *
# 3         -
# 28     14.5
# 30     14.6
# 23    15.41
# 29     15.5
# 6     15.84
# 0     16.46
# 26     16.7
# 21    16.87
# 27     16.9
# 24    17.05
# 22     17.3
# 11     17.4
# 16    17.42
# 12     17.6
# 15    17.82
# 14    17.98
# 13       18
# 9      18.3
# 18    18.52
# 31     18.6
# 4     18.61
# 2     18.61
# 10     18.9
# 25     18.9
# 17    19.47
# 19     19.9
# 20    20.01
# 8     20.22
# 7     20.22
# 5     20.22
# Name: qsec, dtype: object

# %%
data.replace(['$', '?', '*', '-'], np.nan)
# Out:
#               car_model    mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4   21.0    6    160  110.0  3.90   2.62  16.46   0   1
# 1         Mazda RX4 Wag   21.0    6    NaN  110.0   NaN  2.875    NaN   0   1
# 2            Datsun 710    NaN    4    108    NaN  3.85    NaN  18.61   1   1
# 3        Hornet 4 Drive  999.0    6    NaN    NaN  3.08  3.215    NaN   1   0
# 4            Datsun 710   22.8    4    NaN   93.0  3.85   2.32  18.61   1   1
# 5               Valiant   18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 6            Duster 360   14.3    8    360  245.0  3.21   3.57  15.84   0   0
# 7             Valiant 2   18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 8               Valiant   18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 9              Merc 280   19.2    6  167.6  123.0  3.92   3.44   18.3   1   0
# 10            Merc 280C   17.8    6  167.6  123.0  3.92   3.44   18.9   1   0
# ...

# %%
data.head()
# Out:
#         car_model    mpg  cyl disp     hp  drat     wt   qsec  vs  am  gear  \
# 0       Mazda RX4   21.0    6  160  110.0  3.90   2.62  16.46   0   1     4
# 1   Mazda RX4 Wag   21.0    6    $  110.0   NaN  2.875      *   0   1     4
# 2      Datsun 710    NaN    4  108    NaN  3.85      ?  18.61   1   1     4
# 3  Hornet 4 Drive  999.0    6  NaN    NaN  3.08  3.215      -   1   0     3
# 4      Datsun 710   22.8    4  NaN   93.0  3.85   2.32  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     1

# %%
data.replace(['$', '?', '*', '-'], np.nan, inplace=True)

# %%
data.head()
# Out:
#         car_model    mpg  cyl disp     hp  drat     wt   qsec  vs  am  gear  \
# 0       Mazda RX4   21.0    6  160  110.0  3.90   2.62  16.46   0   1     4
# 1   Mazda RX4 Wag   21.0    6  NaN  110.0   NaN  2.875    NaN   0   1     4
# 2      Datsun 710    NaN    4  108    NaN  3.85    NaN  18.61   1   1     4
# 3  Hornet 4 Drive  999.0    6  NaN    NaN  3.08  3.215    NaN   1   0     3
# 4      Datsun 710   22.8    4  NaN   93.0  3.85   2.32  18.61   1   1     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     1

# %%
data.isnull().sum()
# Out:
# car_model    0
# mpg          1
# cyl          0
# disp         3
# hp           2
# drat         1
# wt           1
# qsec         2
# vs           0
# am           0
# gear         0
# carb         0
# dtype: int64

# %% [markdown]
# [markdown]
#
# if you have < 5% records with missing values
# we drop / delete missing value records we drop them
#
# otherwise we treat them

# %%
data.dropna()
# Out:
#               car_model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6    160  110.0  3.90   2.62  16.46   0   1
# 5               Valiant  18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 6            Duster 360  14.3    8    360  245.0  3.21   3.57  15.84   0   0
# 7             Valiant 2  18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 8               Valiant  18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 9              Merc 280  19.2    6  167.6  123.0  3.92   3.44   18.3   1   0
# 10            Merc 280C  17.8    6  167.6  123.0  3.92   3.44   18.9   1   0
# 11           Merc 450SE  16.4    8  275.8  180.0  3.07   4.07   17.4   0   0
# 12           Merc 450SL  17.3    8  275.8  180.0  3.07   3.73   17.6   0   0
# 13          Merc 450SLC  15.2    8  275.8  180.0  3.07   3.78     18   0   0
# 14   Cadillac Fleetwood  10.4    8    472  205.0  2.93   5.25  17.98   0   0
# ...

# %%
data.dropna().shape[0]
# Out:
# 28

# %%
def total_percentage_of_missing_values(data):
    """ This formula works for all data
    percentage of values 
    """
    return (data.shape[0] - data.dropna().shape[0]) / data.shape[0] * 100

# %%
total_percentage_of_missing_values(data)
# Out:
# 12.5

# %%
data.fillna(100)
# Out:
#               car_model    mpg  cyl   disp     hp    drat     wt   qsec  vs  \
# 0             Mazda RX4   21.0    6    160  110.0    3.90   2.62  16.46   0
# 1         Mazda RX4 Wag   21.0    6    100  110.0  100.00  2.875    100   0
# 2            Datsun 710  100.0    4    108  100.0    3.85    100  18.61   1
# 3        Hornet 4 Drive  999.0    6    100  100.0    3.08  3.215    100   1
# 4            Datsun 710   22.8    4    100   93.0    3.85   2.32  18.61   1
# 5               Valiant   18.1    6    225  105.0    2.76   3.46  20.22   1
# 6            Duster 360   14.3    8    360  245.0    3.21   3.57  15.84   0
# 7             Valiant 2   18.1    6    225  105.0    2.76   3.46  20.22   1
# 8               Valiant   18.1    6    225  105.0    2.76   3.46  20.22   1
# 9              Merc 280   19.2    6  167.6  123.0    3.92   3.44   18.3   1
# 10            Merc 280C   17.8    6  167.6  123.0    3.92   3.44   18.9   1
# ...

# %%
data.fillna(method='ffill') # forward fill
# Out:
#               car_model    mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4   21.0    6    160  110.0  3.90   2.62  16.46   0   1
# 1         Mazda RX4 Wag   21.0    6    160  110.0  3.90  2.875  16.46   0   1
# 2            Datsun 710   21.0    4    108  110.0  3.85  2.875  18.61   1   1
# 3        Hornet 4 Drive  999.0    6    108  110.0  3.08  3.215  18.61   1   0
# 4            Datsun 710   22.8    4    108   93.0  3.85   2.32  18.61   1   1
# 5               Valiant   18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 6            Duster 360   14.3    8    360  245.0  3.21   3.57  15.84   0   0
# 7             Valiant 2   18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 8               Valiant   18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 9              Merc 280   19.2    6  167.6  123.0  3.92   3.44   18.3   1   0
# 10            Merc 280C   17.8    6  167.6  123.0  3.92   3.44   18.9   1   0
# ...

# %% [markdown]
#  [markdown]
#
# missing value can be in the form of numbers as well

# %%
data.fillna(method='ffill')
# Out:
#               car_model    mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4   21.0    6    160  110.0  3.90   2.62  16.46   0   1
# 1         Mazda RX4 Wag   21.0    6    160  110.0  3.90  2.875  16.46   0   1
# 2            Datsun 710   21.0    4    108  110.0  3.85  2.875  18.61   1   1
# 3        Hornet 4 Drive  999.0    6    108  110.0  3.08  3.215  18.61   1   0
# 4            Datsun 710   22.8    4    108   93.0  3.85   2.32  18.61   1   1
# 5               Valiant   18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 6            Duster 360   14.3    8    360  245.0  3.21   3.57  15.84   0   0
# 7             Valiant 2   18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 8               Valiant   18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 9              Merc 280   19.2    6  167.6  123.0  3.92   3.44   18.3   1   0
# 10            Merc 280C   17.8    6  167.6  123.0  3.92   3.44   18.9   1   0
# ...

# %% [markdown]
# [markdown]
#
# mean replacement is the most popular technique for continuous data missing value treatment

# %%
data.describe()
# Out:
#               mpg        cyl          hp       drat         vs         am  \
# count   31.000000  32.000000   30.000000  31.000000  32.000000  32.000000
# mean    51.316129   6.187500  148.733333   3.541935   0.468750   0.437500
# std    175.986930   1.712148   68.753901   0.572389   0.507007   0.504016
# min     10.400000   4.000000   52.000000   2.760000   0.000000   0.000000
# 25%     15.350000   4.000000  105.000000   3.070000   0.000000   0.000000
# 50%     18.100000   6.000000  123.000000   3.620000   0.000000   0.000000
# 75%     22.150000   8.000000  180.000000   3.920000   1.000000   1.000000
# max    999.000000   8.000000  335.000000   4.930000   1.000000   1.000000
#
#             gear       carb
# count  32.000000  32.000000
# mean    3.656250   2.718750
# std     0.745281   1.689328
# min     3.000000   1.000000
# 25%     3.000000   1.000000
# 50%     3.500000   2.000000
# 75%     4.000000   4.000000
# max     5.000000   8.000000

# %% [markdown]
# [markdown]
#
# max value is 999 is crazy for mpg
# it is actually a missing value
#
# standard deviation of mpg is big
#
# mean is just 51 and standard deviation is 175
#
# This indicates bad data

# %%
data.loc[data.mpg>100]
# Out:
#         car_model    mpg  cyl disp  hp  drat     wt qsec  vs  am  gear  carb
# 3  Hornet 4 Drive  999.0    6  NaN NaN  3.08  3.215  NaN   1   0     3     1

# %%
data.loc[data.mpg==999, 'mpg'] = np.nan

# %%
data
# Out:
#               car_model   mpg  cyl   disp     hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6    160  110.0  3.90   2.62  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6    NaN  110.0   NaN  2.875    NaN   0   1
# 2            Datsun 710   NaN    4    108    NaN  3.85    NaN  18.61   1   1
# 3        Hornet 4 Drive   NaN    6    NaN    NaN  3.08  3.215    NaN   1   0
# 4            Datsun 710  22.8    4    NaN   93.0  3.85   2.32  18.61   1   1
# 5               Valiant  18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 6            Duster 360  14.3    8    360  245.0  3.21   3.57  15.84   0   0
# 7             Valiant 2  18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 8               Valiant  18.1    6    225  105.0  2.76   3.46  20.22   1   0
# 9              Merc 280  19.2    6  167.6  123.0  3.92   3.44   18.3   1   0
# 10            Merc 280C  17.8    6  167.6  123.0  3.92   3.44   18.9   1   0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# car_model    32 non-null object
# mpg          30 non-null float64
# cyl          32 non-null int64
# disp         29 non-null object
# hp           30 non-null float64
# drat         31 non-null float64
# wt           31 non-null object
# qsec         30 non-null object
# vs           32 non-null int64
# am           32 non-null int64
# gear         32 non-null int64
# carb         32 non-null int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.1+ KB

# %%
data.disp = data.disp.astype('float')

# %%
data.wt = data.wt.astype('float')
data.qsec = data.qsec.astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# car_model    32 non-null object
# mpg          30 non-null float64
# cyl          32 non-null int64
# disp         29 non-null float64
# hp           30 non-null float64
# drat         31 non-null float64
# wt           31 non-null float64
# qsec         30 non-null float64
# vs           32 non-null int64
# am           32 non-null int64
# gear         32 non-null int64
# carb         32 non-null int64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 3.1+ KB

# %%
data.fillna(data.mean(), inplace=True)

# %%
data
# Out:
#               car_model        mpg  cyl        disp          hp      drat  \
# 0             Mazda RX4  21.000000    6  160.000000  110.000000  3.900000
# 1         Mazda RX4 Wag  21.000000    6  233.365517  110.000000  3.541935
# 2            Datsun 710  19.726667    4  108.000000  148.733333  3.850000
# 3        Hornet 4 Drive  19.726667    6  233.365517  148.733333  3.080000
# 4            Datsun 710  22.800000    4  233.365517   93.000000  3.850000
# 5               Valiant  18.100000    6  225.000000  105.000000  2.760000
# 6            Duster 360  14.300000    8  360.000000  245.000000  3.210000
# 7             Valiant 2  18.100000    6  225.000000  105.000000  2.760000
# 8               Valiant  18.100000    6  225.000000  105.000000  2.760000
# 9              Merc 280  19.200000    6  167.600000  123.000000  3.920000
# 10            Merc 280C  17.800000    6  167.600000  123.000000  3.920000
# 11           Merc 450SE  16.400000    8  275.800000  180.000000  3.070000
# ...

# %% [markdown]
# [markdown]
#
# we can also use predictive ml models to predict missing values
#
# In this case missing value prediction variable should not be part of final predictive model
#
# cyclic reference can give you bad results

# %%
data = pd.read_csv('data/mtcars_duplicates.csv')

# %%
data
# Out:
#               car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110   NaN  2.875  17.02   0   1
# 2            Datsun 710  21.0    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  22.8    6  108.0  110  3.08  3.215  19.44   1   0
# 4            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 5             Valiant 2  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 7              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 8               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 9            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 10    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# ...

# %%
data.drop_duplicates()
# Out:
#               car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110   NaN  2.875  17.02   0   1
# 2            Datsun 710  21.0    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  22.8    6  108.0  110  3.08  3.215  19.44   1   0
# 4            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 5             Valiant 2  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 7              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 9            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 10    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 11             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# ...

# %%
data.drop_duplicates(['hp', 'wt', 'qsec']) # select 2 or 3 key fields
# Out:
#               car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110   NaN  2.875  17.02   0   1
# 2            Datsun 710  21.0    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  22.8    6  108.0  110  3.08  3.215  19.44   1   0
# 5             Valiant 2  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 7              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 9            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 10    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 11             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 12          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 13       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# ...

# %% [markdown]
# [markdown]
#
# finding 2 to 3 key fields for duplicate analysis is important
# This comes from business knowledge
#
# postcode along with email can be key fields

# %%
data.sort_values(['mpg'])
# Out:
#               car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 25  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 24   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 21           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 33           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 9            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 26    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 10    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 40        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 23          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 32          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 20          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# ...

# %%
data.sort_values(['mpg', 'hp'], ascending=False)
# Out:
#               car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 13       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 29       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 11             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 27             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 37         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 12          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 28          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 35            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 36        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 3        Hornet 4 Drive  22.8    6  108.0  110  3.08  3.215  19.44   1   0
# 4            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# ...

# %% [markdown]
# Outliers
#
# Using boxplot we can identify outliers

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(data.mpg)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x215d8c06d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x215d8c2e358>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x215d8c24860>],
#  'medians': [<matplotlib.lines.Line2D at 0x215d8c2e9b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x215d8c2ecf8>],
#  'means': []}

# %% [markdown]
# In the above graph we can identify in which quarter we have most cars in.
#
# Outliers are also seen as dots.

# %%
data.boxplot()

# %%
data.mpg.plot(kind='box')

# %%
data.carb.plot(kind='box')

# %% [markdown]
# Outlier is more than 3 standard deviations up or down

# %%
data[data.hp > data.hp.mean() + 2.6 * data.hp.std() ]
# Out:
#         car_model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 40  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %%
data = data[data.hp < data.hp.mean() + 2.6 * data.hp.std() ]

# %%
data = data[data.hp < 300]

# %%
data = data[data.mpg < 30]

# %%
data.wt.plot(kind='box')

# %%
data[data.wt < 5].sort_values(['wt'], ascending=False)
# Out:
#            car_model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 18        Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# 34  Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# 22  Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# 33        Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# 21        Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# 23       Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# 19        Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# 9         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 31  Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# 8            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 14         Valiant 2  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# ...

# %% [markdown]
# Can we replace with the outlier with the maximum value?
#
# Answer is yes no
#
# By replacing with maximum value that may be as good a removing it.

# %% [markdown]
# # Group and aggregation

# %%
datagroup = data.groupby('am')

# %%
datagroup.mean()
# Out:
#           mpg       cyl        disp          hp    drat        wt       qsec  \
# am
# 0   16.612000  7.120000  291.252000  162.240000  3.1932  3.822960  18.076800
# 1   21.777778  5.111111  150.255556  123.444444  4.0075  2.547778  17.211111
#
#           vs      gear      carb
# am
# 0   0.400000  3.120000  2.640000
# 1   0.444444  4.333333  2.777778

# %%
datagroup.describe()
# Out:
#      mpg                                                      cyl            \
#    count       mean       std   min   25%   50%   75%   max count      mean
# am
# 0   25.0  16.612000  3.034293  10.4  14.7  17.3  18.1  22.8  25.0  7.120000
# 1    9.0  21.777778  3.379637  15.8  21.0  21.0  22.8  27.3   9.0  5.111111
#
#     ... gear       carb
#     ...  75%  max count      mean       std  min  25%  50%  75%  max
# am  ...
# 0   ...  3.0  4.0  25.0  2.640000  1.287116  1.0  1.0  3.0  4.0  4.0
# 1   ...  5.0  5.0   9.0  2.777778  1.787301  1.0  1.0  2.0  4.0  6.0
#
# [2 rows x 80 columns]

# %% [markdown]
# Grouping and aggregating

# %%
datagroup = data.groupby('gear')

# %%
datagroup.mean()
# Out:
#             mpg       cyl        disp          hp      drat        wt  \
# gear
# 3     16.322727  7.272727  308.113636  167.590909  3.094091  3.875182
# 4     21.188889  5.111111  137.644444  105.555556  3.943750  2.796667
# 5     20.500000  6.000000  205.433333  176.666667  4.090000  2.693333
#
#            qsec        vs        am      carb
# gear
# 3     18.019091  0.318182  0.000000  2.454545
# 4     18.188889  0.777778  0.666667  2.777778
# 5     15.566667  0.000000  1.000000  4.000000

# %%
datagroup.describe()
# Out:
#        mpg                                                         cyl  \
#      count       mean       std   min    25%    50%    75%   max count
# gear
# 3     22.0  16.322727  3.119208  10.4  14.70  15.95  18.10  22.8  22.0
# 4      9.0  21.188889  2.726923  17.8  19.20  21.00  21.40  27.3   9.0
# 5      3.0  20.500000  5.146844  15.8  17.75  19.70  22.85  26.0   3.0
#
#                 ...   am       carb                                          \
#           mean  ...  75%  max count      mean       std  min  25%  50%  75%
# gear            ...
# 3     7.272727  ...  0.0  0.0  22.0  2.454545  1.262170  1.0  1.0  2.0  4.0
# 4     5.111111  ...  1.0  1.0   9.0  2.777778  1.481366  1.0  1.0  4.0  4.0
# 5     6.000000  ...  1.0  1.0   3.0  4.000000  2.000000  2.0  3.0  4.0  5.0
#
#
#       max
# gear
# 3     4.0
# 4     4.0
# 5     6.0
#
# [3 rows x 80 columns]

# %%
datagroup = data.groupby(['am', 'gear'])

# %%
datagroup.mean()
# Out:
#                mpg       cyl        disp          hp      drat        wt  \
# am gear
# 0  3     16.322727  7.272727  308.113636  167.590909  3.094091  3.875182
#    4     18.733333  6.000000  167.600000  123.000000  3.920000  3.440000
# 1  4     22.416667  4.666667  122.666667   96.833333  3.958000  2.475000
#    5     20.500000  6.000000  205.433333  176.666667  4.090000  2.693333
#
#               qsec        vs      carb
# am gear
# 0  3     18.019091  0.318182  2.454545
#    4     18.500000  1.000000  4.000000
# 1  4     18.033333  0.666667  2.166667
#    5     15.566667  0.000000  4.000000

# %%
datagroup.mean().to_excel('group_mean.xlsx')

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D276-574F
#
#  Directory of C:\Users\Bineesh\workspace\data_science\datamites
#
# 04-08-2019  10:26    <DIR>          .
# 04-08-2019  10:26    <DIR>          ..
# 04-08-2019  09:47    <DIR>          .ipynb_checkpoints
# 02-08-2019  18:00    <DIR>          assignments
# 03-08-2019  15:49            51,913 basics_of_matplotlib.ipynb
# 03-08-2019  11:27            25,024 basics_of_numpy.ipynb
# 03-08-2019  11:24             4,230 basics_of_numpy.py
# 03-08-2019  14:14            91,872 basics_of_pandas.ipynb
# 24-07-2019  09:06             3,996 basics_of_python.py
# 03-08-2019  15:57    <DIR>          data
# 24-07-2019  09:13             1,482 datamites.org
# 21-07-2019  09:33            27,361 datamites_1.ipynb
# 04-08-2019  10:26           360,649 data_treatment.ipynb
# 04-08-2019  10:26             5,825 group_mean.xlsx
# 22-07-2019  12:36    <DIR>          images
# 24-07-2019  09:07             7,245 statistics.md
# ...
