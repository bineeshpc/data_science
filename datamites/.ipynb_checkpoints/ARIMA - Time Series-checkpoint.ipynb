# %% [markdown]
# # Time Series Forescasting

# %%
import pandas as pd
from pandas import datetime
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## . Demo on strptime function
day = datetime.strptime('february/1-2019','%B/%d-%Y')
print(day)
print(day.month)
# Out:
# 2019-02-01 00:00:00
# 2

# %%
newdate = 'Jan-19-22'
print(datetime.strptime(newdate,'%b-%y-%d'))
# Out:
# 2019-01-22 00:00:00

# %%
def parser(x):
    return datetime.strptime(x,'%Y-%m')
sales = pd.read_csv('data/sales-cars.csv',index_col=0, parse_dates=[0] ,date_parser=parser)
sales.head()
# Out:
#             Sales
# Month
# 2016-01-01    266
# 2016-02-01    146
# 2016-03-01    183
# 2016-04-01    119
# 2016-05-01    180

# %%
sales.plot()

# %% [markdown]
# Stationary means mean, variance and covariance is constant over periods.

# %%
#ACF -> Auto Colleration Function 
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(sales)
plt.show()

# %% [markdown]
# ### Converting series to stationary

# %%
sales.head()
# Out:
#             Sales
# Month
# 2016-01-01    266
# 2016-02-01    146
# 2016-03-01    183
# 2016-04-01    119
# 2016-05-01    180

# %%
sales.shift(1)
# Out:
#             Sales
# Month
# 2016-01-01    NaN
# 2016-02-01  266.0
# 2016-03-01  146.0
# 2016-04-01  183.0
# 2016-05-01  119.0
# 2016-06-01  180.0
# 2016-07-01  169.0
# 2016-08-01  232.0
# 2016-09-01  225.0
# 2016-10-01  193.0
# 2016-11-01  123.0
# 2016-12-01  337.0
# 2017-01-01  186.0
# 2017-02-01  194.0
# 2017-03-01  150.0
# 2017-04-01  210.0
# 2017-05-01  273.0
# 2017-06-01  191.0
# 2017-07-01  287.0
# 2017-08-01  226.0
# 2017-09-01  304.0
# 2017-10-01  290.0
# 2017-11-01  422.0
# 2017-12-01  265.0
# 2018-01-01  342.0
# 2018-02-01  340.0
# 2018-03-01  440.0
# 2018-04-01  316.0
# 2018-05-01  439.0
# 2018-06-01  401.0
# 2018-07-01  390.0
# 2018-08-01  490.0
# 2018-09-01  408.0
# 2018-10-01  490.0
# 2018-11-01  420.0
# 2018-12-01  520.0

# %%
sales_diff = sales.diff(periods=1)
# integrated of order 1, denoted by d (for diff), one of the parameter of ARIMA model

# %%
sales.head()
# Out:
#             Sales
# Month
# 2016-01-01    266
# 2016-02-01    146
# 2016-03-01    183
# 2016-04-01    119
# 2016-05-01    180

# %%
sales_diff = sales_diff[1:]
sales_diff.head()
# Out:
#             Sales
# Month
# 2016-02-01 -120.0
# 2016-03-01   37.0
# 2016-04-01  -64.0
# 2016-05-01   61.0
# 2016-06-01  -11.0

# %%
plot_acf(sales_diff)
plt.show()

# %%
sales_diff.plot()

# %%
X = sales.values.astype('float')
train = X[0:27] # 27 data as train data
test = X[26:]  # 9 data as test data
predictions = []

# %%
train.size
# Out:
# 27

# %% [markdown]
# # ARIMA model

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
#p,d,q  p = periods taken for autoregressive model
#d -> Integrated order, difference
# q periods in moving average model
model_arima = ARIMA(train,order=(3,1,2))
model_arima_fit = model_arima.fit()
print(model_arima_fit.aic)
# Out:
# 292.6686238693939

# %%
predictions= model_arima_fit.forecast(steps=10)[0]
predictions
# Out:
# array([383.93155372, 332.47745041, 419.91250251, 389.17777808,
#        409.21394719, 373.91758766, 413.84898342, 423.08202305,
#        443.47782908, 422.17587845])

# %%
plt.plot(test, color='green')
plt.plot(predictions,color='red')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
np.sqrt(mean_squared_error(test, predictions))
# Out:
# 62.4626715625451
